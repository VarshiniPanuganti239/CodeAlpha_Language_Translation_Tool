# %%
# !pip install deep-translator
# !pip install langdetect
# !pip install pandas
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.3/42.3 kB 2.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 981.5/981.5 kB 32.4 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for langdetect: filename=langdetect-1.0.9-py3-none-any.whl size=993223 sha256=5450cbf4dfecdc4639afe60e5feb51c0631456f765f789c9b90e2d887abab233
#   Stored in directory: /root/.cache/pip/wheels/c1/67/88/e844b5b022812e15a52e4eaa38a1e709e99f06f6639d7e3ba7
# Successfully built langdetect
# ...

# %%
from deep_translator import GoogleTranslator
from langdetect import detect
import pandas as pd

# %%
text = "Bonjour tout le monde"

language = detect(text)

print("Detected Language:", language)
# Out:
# Detected Language: fr

# %%
def translate_text(text, target_language):

    translated = GoogleTranslator(
        source='auto',
        target=target_language
    ).translate(text)

    return translated

# %%
sentence = "Artificial Intelligence is changing the world."

translated_text = translate_text(
    sentence,
    "hi"
)

print("Original:")
print(sentence)

print("\nTranslated:")
print(translated_text)
# Out:
# Original:
# Artificial Intelligence is changing the world.
#
# Translated:
# आर्टिफिशियल इंटेलिजेंस दुनिया को बदल रहा है।

# %%
languages = {
    "French": "fr",
    "German": "de",
    "Spanish": "es",
    "Hindi": "hi",
    "Telugu": "te",
    "Tamil": "ta",
    "Japanese": "ja"
}

text = "Machine Learning is fascinating."

for language_name, code in languages.items():

    translated = translate_text(
        text,
        code
    )

    print(f"{language_name}:")
    print(translated)
    print("-" * 50)
# Out:
# French:
# L’apprentissage automatique est fascinant.
# --------------------------------------------------
# German:
# Maschinelles Lernen ist faszinierend.
# --------------------------------------------------
# Spanish:
# El aprendizaje automático es fascinante.
# --------------------------------------------------
# Hindi:
# मशीन लर्निंग आकर्षक है.
# --------------------------------------------------
# Telugu:
# మెషిన్ లెర్నింగ్ మనోహరమైనది.
# --------------------------------------------------
# Tamil:
# இயந்திர கற்றல் கவர்ச்சிகரமானது.
# --------------------------------------------------
# Japanese:
# 機械学習は魅力的です。
# --------------------------------------------------

# %%
history = []

sample_text = "Welcome to Artificial Intelligence"

translated = translate_text(
    sample_text,
    "fr"
)

history.append(
    {
        "Original": sample_text,
        "Translated": translated
    }
)

history_df = pd.DataFrame(history)

history_df
# Out:
#                              Original  \
# 0  Welcome to Artificial Intelligence
#
#                                    Translated
# 0  Bienvenue dans l'intelligence artificielle

# %%
sample_dataset = [
    {
        "English": "Good Morning",
        "French": "Bonjour"
    },
    {
        "English": "How are you?",
        "French": "Comment allez-vous?"
    },
    {
        "English": "Machine Learning is powerful",
        "French": "L'apprentissage automatique est puissant"
    },
    {
        "English": "Artificial Intelligence is changing the world",
        "French": "L'intelligence artificielle change le monde"
    },
    {
        "English": "Welcome to CodeAlpha Internship",
        "French": "Bienvenue au stage CodeAlpha"
    }
]

dataset_df = pd.DataFrame(sample_dataset)

dataset_df
# Out:
#                                          English  \
# 0                                   Good Morning
# 1                                   How are you?
# 2                   Machine Learning is powerful
# 3  Artificial Intelligence is changing the world
# 4                Welcome to CodeAlpha Internship
#
#                                         French
# 0                                      Bonjour
# 1                          Comment allez-vous?
# 2     L'apprentissage automatique est puissant
# 3  L'intelligence artificielle change le monde
# 4                 Bienvenue au stage CodeAlpha

# %%
correct = 0

for index, row in dataset_df.iterrows():

    translated = translate_text(
        row["English"],
        "fr"
    )

    print("Original :", row["English"])
    print("Expected :", row["French"])
    print("Predicted:", translated)
    print("-"*50)
# Out:
# Original : Good Morning
# Expected : Bonjour
# Predicted: Bonjour
# --------------------------------------------------
# Original : How are you?
# Expected : Comment allez-vous?
# Predicted: Comment vas-tu?
# --------------------------------------------------
# Original : Machine Learning is powerful
# Expected : L'apprentissage automatique est puissant
# Predicted: L'apprentissage automatique est puissant
# --------------------------------------------------
# Original : Artificial Intelligence is changing the world
# Expected : L'intelligence artificielle change le monde
# Predicted: L'intelligence artificielle change le monde
# --------------------------------------------------
# Original : Welcome to CodeAlpha Internship
# Expected : Bienvenue au stage CodeAlpha
# Predicted: Bienvenue au stage CodeAlpha
# --------------------------------------------------

# %%
app.py
